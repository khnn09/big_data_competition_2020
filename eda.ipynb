# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.rc("font", family = "Malgun Gothic")
plt.rc("axes", unicode_minus = False)

# %%
df = pd.read_csv("1029_1037_20개동매출까지다해썽.csv")

# %%
df = df.iloc[:,2:]

# %%
df.drop(["행정구역_x","행정구역_y"], axis = 1, inplace = True)

# %%
df.동.unique()
# Out:
# array(['종로1.2.3.4가동', '창신3동', '명동', '이촌2동', '돈암2동', '응암2동', '서교동', '가양1동',
#        '시흥2동', '여의동', '신길4동', '삼성동', '서초3동', '논현2동', '압구정동', '청담동',
#        '역삼1동', '개포1동', '잠실7동', '둔촌1동'], dtype=object)

# %%
len(df.columns)
# Out:
# 22

# %%
df.columns
# Out:
# Index(['날짜', '생활인구수', '시도명', '구', '동', '분기', '월', '구별_유동인구', '구신규', '전국신규',
#        '서울신규', '2020년 1분기전체점포수', '2020년 1분기프랜차이즈점포수', '2020년 1분기일반점포수',
#        '2020년 2분기전체점포수', '2020년 2분기프랜차이즈점포수', '2020년 2분기일반점포수', '동_전체음식점수',
#        '동_프랜차이즈음식점수', '동_일반음식점수', 'TS_YMD', '동_매출합계'],
#       dtype='object')

# %%
sns.set(font_scale = 1.2, font="Malgun Gothic")

# %%
for k in df.columns[7:21]:
    sns.lmplot(data = df, x= k, y = "동_매출합계", palette = "muted", line_kws = {'color':'g'})

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(data = df, x= "구별_유동인구", y = "동_매출합계", hue = "동")
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(data = df, x= "구신규", y = "동_매출합계", hue = "동")
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(data = df, x= "전국신규", y = "동_매출합계", hue = "동")
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(data = df, x= "동_프랜차이즈음식점수", y = "동_매출합계", hue = "동")
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(data = df, x= "동_전체음식점수", y = "동_매출합계", hue = "동")
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(data = df, x= "동_일반음식점수", y = "동_매출합계", hue = "동")
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
plt.figure(figsize = (8,7))
sns.lmplot(data = df, x= "동_일반음식점수", y = "동_매출합계", hue = "동")
#plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
plt.figure(figsize = (8,7))
sns.lmplot(data = df, x= "전국신규", y = "동_매출합계", hue = "동")
#plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)

# %%
sns.lmplot(data = df, x= "동_프랜차이즈음식점수", y = "동_매출합계", hue = "동")

# %%
df2 = pd.read_csv("동_매출_1920.csv")

# %%
#df2 = df2.iloc[:,1:]

# %%
df2["날짜"] = pd.to_datetime(df2["TS_YMD"], format = "%Y%m%d")

# %%
df2["month"] = df2["날짜"].dt.month

# %%
df2 = df2[df2.month.isin([1,2,3,4,5,6,7,8])]

# %%
df2["Y"] = df2["날짜"].dt.year

# %%
import datetime

# %%
#df2["월일"] = df["날짜"].map(lambda x : x.strftime("%m%d"))

# %%
dong = ['가양1동', '개포1동', '논현2동', '돈암2동', '둔촌1동', '명동', '삼성동', '서교동', '서초3동',
       '시흥2동', '신길4동', '압구정동', '여의동', '역삼1동', '응암2동', '이촌2동', '잠실7동',
       '종로1.2.3.4가동', '창신3동', '청담동']

# %%
df2 = df2[df2.동.isin(dong)]

# %%
df2.동.unique()
# Out:
# array(['가양1동', '개포1동', '논현2동', '돈암2동', '둔촌1동', '명동', '삼성동', '서교동', '서초3동',
#        '시흥2동', '신길4동', '압구정동', '여의동', '역삼1동', '응암2동', '이촌2동', '잠실7동',
#        '종로1.2.3.4가동', '창신3동', '청담동'], dtype=object)

# %%
plt.figure(figsize = (8,10))
sns.boxplot(y = "동",x = "동_매출합계", data = df2)
plt.title("동별 매출액 분포")
# Out:
# Text(0.5, 1.0, '동별 매출액 분포')

# %%
hotd = ['역삼1동', '여의동', '종로1.2.3.4가동', '서교동', '명동', '서초3동', '청담동', '압구정동', '가양1동', '논현2동']

# %%
cold = ['삼성동', '시흥2동', '신길4동', '응암2동', '돈암2동', '창신3동', '이촌2동', '잠실7동', '개포1동', '둔촌1동']

# %%
hot = df2[(df2.동.isin(hotd))]
col = df2[(df2.동.isin(cold))]
hot["핫플"] = "핫"
col["비핫플"] = "비핫"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
hot19 = df2[(df2.동.isin(hotd))&(df2.Y == 2019)]
col19 = df2[(df2.동.isin(cold))&(df2.Y == 2019)]

# %%
hot20 = df2[(df2.동.isin(hotd))&(df2.Y == 2020)]
col20 = df2[(df2.동.isin(cold))&(df2.Y == 2020)]

# %%
sns.set_palette("pastel")

# %%
plt.figure(figsize = (6,10))
sns.violinplot(data = hot , y= "동", x = "동_매출합계", hue = "Y", split = True)
plt.title("핫플 동별 매출 분포")
# Out:
# Text(0.5, 1.0, '핫플 동별 매출 분포')

# %%
plt.figure(figsize = (6,10))
sns.violinplot(data = col , y= "동", x = "동_매출합계", hue = "Y", split = True)
plt.title("비핫플 동별 매출 분포")
# Out:
# Text(0.5, 1.0, '비핫플 동별 매출 분포')

# %%
plt.figure(figsize = (14,6))
sns.violinplot(data = hot, x = "month", y = "동_매출합계", hue = "Y", split = True)
plt.title("핫플 월별 매출 분포")
# Out:
# Text(0.5, 1.0, '핫플 월별 매출 분포')

# %%
plt.figure(figsize = (14,6))
sns.violinplot(data = col, x = "month", y = "동_매출합계", hue = "Y", split = True)
plt.title("비핫플 월별 매출 분포")
# Out:
# Text(0.5, 1.0, '비핫플 월별 매출 분포')

# %%
sns.set_palette("deep")

# %% [markdown]
# # 2020 핫플 비핫플

# %% [markdown]
# ## 평균

# %%
res1 = hot20.groupby(["month"]).mean().동_매출합계.reset_index()
res2 = col20.groupby(["month"]).mean().동_매출합계.reset_index()
res1["핫플"] = "핫"
res2["핫플"] = "비핫"
res_con = pd.concat([res1, res2])

# %%
rres_con = res_con.pivot("month", "핫플", "동_매출합계")

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res1,
    x = "month",
    y = "동_매출합계")

for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/100000), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2020년 핫플 일결제액 월별 평균')
# Out:
# Text(0.5, 1.0, '2020년 핫플 일결제액 월별 평균')

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res2,
    x = "month",
    y = "동_매출합계")
for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/100), (left+width/2, height*1.01), ha = 'center')

plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2020년 비핫플 일결제액 월별 평균')
# Out:
# Text(0.5, 1.0, '2020년 비핫플 일결제액 월별 평균')

# %% [markdown]
# ## 합

# %%
res1 = hot20.groupby(["month"]).sum().동_매출합계.reset_index()
res2 = col20.groupby(["month"]).sum().동_매출합계.reset_index()
res1["핫플"] = "핫"
res2["핫플"] = "비핫"
res_con = pd.concat([res1, res2])

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res1,
    x = "month",
    y = "동_매출합계")
#y = sns.barplot(
 #   data = res2,
 #   x = "month",
 #   y = "동_매출합계", ax = ax1)
for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/10000000), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2020년 핫플 일결제액 월별 합')
# Out:
# Text(0.5, 1.0, '2020년 핫플 일결제액 월별 합')

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res2,
    x = "month",
    y = "동_매출합계")
for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/100000), (left+width/2, height*1.01), ha = 'center')

plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2020년 비핫플 일결제액 월별 합')
# Out:
# Text(0.5, 1.0, '2020년 비핫플 일결제액 월별 합')

# %% [markdown]
# # 2019 핫플 비핫플

# %% [markdown]
# ## 평균

# %%
res1 = hot19.groupby(["month"]).mean().동_매출합계.reset_index()
res2 = col19.groupby(["month"]).mean().동_매출합계.reset_index()
res1["Y"] = 2019
res2["Y"] = 2020
res_con = pd.concat([res1, res2])

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res1,
    x = "month",
    y = "동_매출합계")

for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/100000), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2019년 핫플 일결제액 월별 평균')
# Out:
# Text(0.5, 1.0, '2019년 핫플 일결제액 월별 평균')

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res2,
    x = "month",
    y = "동_매출합계")

for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/100), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2019년 비핫플 일결제액 월별 평균')
# Out:
# Text(0.5, 1.0, '2019년 비핫플 일결제액 월별 평균')

# %% [markdown]
# ## 합

# %%
res1 = hot19.groupby(["month"]).sum().동_매출합계.reset_index()
res2 = col19.groupby(["month"]).sum().동_매출합계.reset_index()
res1["Y"] = 2019
res2["Y"] = 2020
res_con = pd.concat([res1, res2])

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res1,
    x = "month",
    y = "동_매출합계")

for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/10000000), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2019년 핫플 일결제액 월별 합')
# Out:
# Text(0.5, 1.0, '2019년 핫플 일결제액 월별 합')

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res2,
    x = "month",
    y = "동_매출합계")

for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/100000), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.title('2019년 비핫플 일결제액 월별 합')
# Out:
# Text(0.5, 1.0, '2019년 비핫플 일결제액 월별 합')

# %% [markdown]
# # 핫플 19/20 비교

# %%
res1 = hot19.groupby(["month"]).mean().동_매출합계.reset_index()
res2 = hot20.groupby(["month"]).mean().동_매출합계.reset_index()
res1["Y"] = 2019
res2["Y"] = 2020
res_con = pd.concat([res1, res2])

# %%
#월별 하루 결제액 평균 
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res_con,
    x = "month",
    y = "동_매출합계",
    hue = "Y")
for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/10000000), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)
plt.title("핫플 19/20 월별 일결제액 평균 비교")

#천만으로 나눔
# Out:
# Text(0.5, 1.0, '핫플 19/20 월별 일결제액 평균 비교')

# %%
hot_rate = pd.DataFrame({"month":[1,2,3,4,5,6,7,8], "매출 비율": res2["동_매출합계"]/res1["동_매출합계"]})

# %%
def hotdong_sum(k):    
    data = hot[hot["동"] == k]
    hot1 = hot19.groupby(["month"]).mean().동_매출합계.reset_index()
    hot2 = hot20.groupby(["month"]).mean().동_매출합계.reset_index()
    
    sns.barplot(data = data, x = "month", y = "동_매출합계", hue = "Y" , ci = None)
    #for p in x.patches:
    #    left, bottom, width, height = p.get_bbox().bounds
    #    plt.annotate("%.f"%(height/10000), (left+width/2, height*1.01), ha = 'center')
    plt.ylabel('월별 결제액 평균', fontsize = 15)
    plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)
    plt.title(f"{k} 19/20 월별 결제액 평균 비교")

# %%
hotdong_sum("청담동")

# %%
hotdong_sum("논현2동")

# %% [markdown]
# # 비핫플 19/20 비교

# %%
res1 = col19.groupby(["month"]).mean().동_매출합계.reset_index()
res2 = col20.groupby(["month"]).mean().동_매출합계.reset_index()
res1["Y"] = 2019
res2["Y"] = 2020
res_con = pd.concat([res1, res2])

# %%
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = res_con,
    x = "month",
    y = "동_매출합계",
    hue = "Y")
for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.f"%(height/10000), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('월별 결제액 평균', fontsize = 15)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)
plt.title("비핫플 19/20 월별 일결제액 평균 비교")

#백만
# Out:
# Text(0.5, 1.0, '비핫플 19/20 월별 일결제액 평균 비교')

# %%
hot19.동.unique()
# Out:
# array(['가양1동', '논현2동', '명동', '서교동', '서초3동', '압구정동', '여의동', '역삼1동',
#        '종로1.2.3.4가동', '청담동'], dtype=object)

# %%
col_rate = pd.DataFrame({"month":[1,2,3,4,5,6,7,8], "매출 비율": res2["동_매출합계"]/res1["동_매출합계"]})

# %%
hot_rate["핫플"] = "핫"
col_rate["핫플"] = "비핫"
rate = pd.concat([hot_rate, col_rate])
plt.figure(figsize = (8,6))
x = sns.barplot(
    data = rate,
    x = "month",
    y = "매출 비율",
    hue = "핫플")
for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate("%.2f"%(height), (left+width/2, height*1.01), ha = 'center')
plt.ylabel('20년도 결제액/19년도 결제액', fontsize = 15)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 2)
plt.title("핫플 비핫플 일결제액 월별 비율 비교")
# Out:
# Text(0.5, 1.0, '핫플 비핫플 일결제액 월별 비율 비교')
